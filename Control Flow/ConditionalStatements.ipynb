# %% [markdown]
# Conditional Statements(if, elif, else)
#
# "If something is true, do this; otherwise, do something else."
#
# ## outline
# 1. **if**
# 2. **if-else**
# 3. **if-elif-else**
# 4. **Nested if,else,elif**

# %%
## if Statement

age=20
if age >= 18:
    print("You are eligible to vote.")

## else Statement
# the else satatement execute a block of code if the condition in the if statement is false.  

age=16
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")


#elif statement
# The elif statement allows you to check multiple conditions in a single if-else block. It stands for "else if" and is used when you have more than two possible conditions to evaluate.   

age = 25
if age < 13:
    print("You are a child.")
elif age < 20:
    print("You are a teenager.")
elif age < 65:
    print("You are an adult.")          
else:
    print("You are a senior citizen.")
# Out:
# You are eligible to vote.
# You are not eligible to vote.
# You are an adult.

# %%
## Nested conditional statements
# we can place one or more if, elif, or else statements inside another if, elif, or else statements inside another if, elif, or else statement to create nested conditional statements. This allows for more complex decision-making based on multiple conditions.

# number is even or odd and positive or negative or zero

num = float(input("Enter a number:"))
if num >0:
    if num%2==0:
        print("the number is positive and even")
    else:
        print("the number is positive and odd")
elif num<0:
    if num%2==0:
        print("the number is negative and even")
    else:
        print("the number is negative and odd")        
else:
    print("the number is zero")
# Out:
# the number is positive and even

# %%
#year is leap year or not
year=int(input("enter a year:"))
if year%400==0:
    print("this is a leap year")
elif year%4==0 and year%100!=0:
    print("this is a leap year")   
else:
    print("this is not a leap year")
# Out:
# this is not a leap year

# %%
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
operation = input("Enter an operation (+, -, *, /): ")

if operation == "+":
    result = num1 + num2
    print("Result:", result)

elif operation == "-":
    result = num1 - num2
    print("Result:", result)

elif operation == "*":
    result = num1 * num2
    print("Result:", result)

elif operation == "/":
    if num2 != 0:
        result = num1 / num2
        print("Result:", result)
    else:
        print("Error: Division by zero is not allowed")

else:
    print("Error: Invalid operation")
# Out:
# Result: 10
