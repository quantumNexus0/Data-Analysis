# %% [markdown]
# # Operators
#  Operators are special symbols or keywords used to perform operations on values and variables.
#
# For Example:
# a=10
# b=5
# print(a+b) # Here + is an operartor
#
# # Types of Operators in Python
#
# Python has several types of operators:
#
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparison Operators
# 4. Logical Operators
# 5. Bitwise Operators
# 6. Membership Operators
# 7. Identity Operators
#
# # 1. Arithmetic Operators
# Used for mathematical calculations.
#
# | Operator | Meaning        | Example   | Result |
# | -------- | -------------- | --------- | ------ |
# | `+`      | Addition       | `10 + 5`  | `15`   |
# | `-`      | Subtraction    | `10 - 5`  | `5`    |
# | `*`      | Multiplication | `10 * 5`  | `50`   |
# | `/`      | Division       | `10 / 5`  | `2.0`  |
# | `//`     | Floor Division | `10 // 3` | `3`    |
# | `%`      | Modulus        | `10 % 3`  | `1`    |
# | `**`     | Exponent       | `2 ** 3`  | `8`    |
#
#
# # 2. Assignment Operators
# Used to assign values to variables.
#
# | Operator | Example   | Same as      |
# | -------- | --------- | ------------ |
# | `=`      | `x = 5`   | `x = 5`      |
# | `+=`     | `x += 2`  | `x = x + 2`  |
# | `-=`     | `x -= 2`  | `x = x - 2`  |
# | `*=`     | `x *= 2`  | `x = x * 2`  |
# | `/=`     | `x /= 2`  | `x = x / 2`  |
# | `//=`    | `x //= 2` | `x = x // 2` |
# | `%=`     | `x %= 2`  | `x = x % 2`  |
# | `**=`    | `x **= 2` | `x = x ** 2` |
#
#
# # 3. Comparison Operators
# Used to compare two values.
#
# | Operator | Meaning                  |
# | -------- | ------------------------ |
# | `==`     | Equal to                 |
# | `!=`     | Not equal to             |
# | `>`      | Greater than             |
# | `<`      | Less than                |
# | `>=`     | Greater than or equal to |
# | `<=`     | Less than or equal to    |
#
#
# # 4. Logical Operators
# Used to combine multiple conditions.
# There are three: and, or, not
#
# # and
# ---> Returns True when both conditions are True.
#
# ex : age = 25
#      print(age > 18 and age < 60)
# o/p: True
#
# # or
# ----> Returns True when at least one condition is True.
# ex: age = 15
#     print(age > 18 or age == 15)
# o/p: True
#
# # not
# ---> Reverses the result.
# ex: x = True
#     print(not x)
# o/p: False
#
# ## 5. Membership Operators
# Used to check whether a value exists inside a sequence such as a string, list, tuple, etc.
#
# There are two:
# 1. in
# 2. not in
#
# ex: 1
# fruits = ["Apple", "Mango", "Banana"]
# print("Mango" in fruits)    #o/p-->True
# print("Orange" in fruits)   #o/p-->False
#
#
# ex:2
# name = "Python"
# print("P" in name)    #o/p--->True
#
# # 6. Identity Operators
# Used to check whether two variables refer to the same object.
# There are two:
# 1. is
# 2. is not
#
# ex:
# x = [1, 2, 3]
# y = x
# print(x is y)
# #o/p---> True here, x and y refer to the same list object.
#
# # 7. Bitwise Operators
# These operate on the binary representation of numbers.
#
# | Operator | Meaning     |    |
# | -------- | ----------- | -- |
# | `&`      | AND         |    |
# | `        | `           | OR |
# | `^`      | XOR         |    |
# | `~`      | NOT         |    |
# | `<<`     | Left shift  |    |
# | `>>`     | Right shift |    |

# %%
a=2
b=4
add_result=a+b
sub_result=a-b
mul_result=a*b
div_result=a/b
floor_div_result=a//b
modules_result=a%b
exponent_result=a**b

print("Addition:", add_result)
print("Subtraction:", sub_result)
print("Multiplication:", mul_result)
print("Division:", div_result)
print("Floor Division:", floor_div_result)
print("Modules:", modules_result)
print("Exponent:", exponent_result)
# Out:
# Addition: 6
# Subtraction: -2
# Multiplication: 8
# Division: 0.5
# Floor Division: 0
# Modules: 2
# Exponent: 16

# %%
###comaprison operators
x=5
y=10
print("x > y:", x > y)
print("x < y:", x < y)
print("x == y:", x == y)
print("x != y:", x != y)
print("x >= y:", x >= y)
print("x <= y:", x <= y)
# Out:
# x > y: False
# x < y: True
# x == y: False
# x != y: True
# x >= y: False
# x <= y: True

# %%
## logical operators (and, or, not)
a = True
b = False
print("a and b:", a and b)
print("a or b:", a or b)
print("not a:", not a)
# Out:
# a and b: False
# a or b: True
# not a: False
